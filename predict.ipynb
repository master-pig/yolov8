# %%
from ultralytics import YOLO
yolo = YOLO("./yolov8n.pt", task="detect")
result = yolo(source="./ultralytics/assets/person.jpg")[0]
print(result)
# Out:
# hello
#
# image 1/1 D:\download\ultralytics-main\ultralytics\assets\person.jpg: 640x480 1 person, 2 potted plants, 77.0ms
# Speed: 2.0ms preprocess, 77.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# ...

# %%
result.boxes.xywh.cpu().numpy()
# Out:
# array([[     1603.7,      2727.6,      1646.1,      2722.9],
#        [     585.23,      2902.4,      1170.5,      1532.4],
#        [     2421.3,      2909.3,      1300.8,      1609.9]], dtype=float32)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.imshow(result.plot()[:,:,::-1])
